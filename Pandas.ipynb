# %%
import pandas as pd
df1 = pd.read_csv("D:/New folder/stack-overflow-developer-survey-2021/survey_results_public.csv",nrows = 1000)
df1
# Out:
#      ResponseId                                         MainBranch  \
# 0             1                     I am a developer by profession
# 1             2             I am a student who is learning to code
# 2             3  I am not primarily a developer, but I write co...
# 3             4                     I am a developer by profession
# 4             5                     I am a developer by profession
# ..          ...                                                ...
# 995         996                        I code primarily as a hobby
# 996         997                     I am a developer by profession
# 997         998                     I am a developer by profession
# 998         999                     I am a developer by profession
# 999        1000                     I am a developer by profession
#
#                                             Employment  \
# 0    Independent contractor, freelancer, or self-em...
# ...

# %%
df1.shape
# Out:
# (1000, 48)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    1000 non-null   int64
#  1   MainBranch                    1000 non-null   object
#  2   Employment                    999 non-null    object
#  3   Country                       1000 non-null   object
#  4   US_State                      152 non-null    object
#  5   UK_Country                    75 non-null     object
#  6   EdLevel                       993 non-null    object
#  7   Age1stCode                    998 non-null    object
#  8   LearnCode                     982 non-null    object
#  9   YearsCode                     938 non-null    object
#  10  YearsCodePro                  737 non-null    object
#  11  DevType                       797 non-null    object
# ...

# %%
df1.head(50)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                     I am a developer by profession
# 1            2             I am a student who is learning to code
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# 5            6             I am a student who is learning to code
# 6            7                        I code primarily as a hobby
# 7            8             I am a student who is learning to code
# 8            9                     I am a developer by profession
# 9           10                     I am a developer by profession
# 10          11                     I am a developer by profession
# 11          12                     I am a developer by profession
# 12          13                     I am a developer by profession
# ...

# %%
df1.tail(25)
# Out:
#      ResponseId                                         MainBranch  \
# 975         976                     I am a developer by profession
# 976         977                     I am a developer by profession
# 977         978                     I am a developer by profession
# 978         979  I am not primarily a developer, but I write co...
# 979         980                     I am a developer by profession
# 980         981                     I am a developer by profession
# 981         982                     I am a developer by profession
# 982         983                     I am a developer by profession
# 983         984                        I code primarily as a hobby
# 984         985                     I am a developer by profession
# 985         986                     I am a developer by profession
# 986         987             I am a student who is learning to code
# 987         988                        I code primarily as a hobby
# ...

# %%
# By using dictionary we can create the dataframe
import pandas as pd
dicts  = {'stu_name' : ['Abhishek'],
         'marks' : [80]}
df = pd.DataFrame(dicts)
df
# Out:
#    stu_name  marks
# 0  Abhishek     80

# %%
# By using dictionary we can create the dataframe
import pandas as pd
dicts  = {'stu_first_name' : ('Abhishek','Akash','Manu','Manju'),
          'stu_last_name':['TG','TG','TS','TM'],
         'marks' : (80,90,75,78)
          ,'email':['abhishek123@gmail.com','akash54@gmail.com','manu87@gmail.com','manju56@gmail.com']}
df = pd.DataFrame(dicts)
df
# Out:
#   stu_first_name stu_last_name  marks                  email
# 0       Abhishek            TG     80  abhishek123@gmail.com
# 1          Akash            TG     90      akash54@gmail.com
# 2           Manu            TS     75       manu87@gmail.com
# 3          Manju            TM     78      manju56@gmail.com

# %%
df1.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
# iloc (integer location)

df1.iloc[[0,1,10,20],[3,4]]
# Out:
#                                               Country US_State
# 0                                            Slovakia      NaN
# 1                                         Netherlands      NaN
# 10  United Kingdom of Great Britain and Northern I...      NaN
# 20                                            Germany      NaN

# %%
df1.iloc[0:10,0:10]
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6             I am a student who is learning to code
# 6           7                        I code primarily as a hobby
# 7           8             I am a student who is learning to code
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# ...

# %%
# loc (it is based on string value in the columns)

df1.loc[[0,5],['Employment','YearsCode']]
# Out:
#                                           Employment YearsCode
# 0  Independent contractor, freelancer, or self-em...       NaN
# 5                                 Student, part-time       NaN

# %%
# loc (it is based on string value in the columns)

df1.loc[0:5,'Employment':'YearsCode']
# Out:
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
# 5                                 Student, part-time
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# 2                                 Russian Federation      NaN        NaN
# 3                                            Austria      NaN        NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN    England
# 5                           United States of America  Georgia        NaN
#
#                                              EdLevel     Age1stCode  \
# ...

# %%
# temporary indexing

df.set_index('stu_first_name')
# Out:
#                stu_last_name  marks                  email
# stu_first_name
# Abhishek                  TG     80  abhishek123@gmail.com
# Akash                     TG     90      akash54@gmail.com
# Manu                      TS     75       manu87@gmail.com
# Manju                     TM     78      manju56@gmail.com

# %%
# main tabel is not changing
df
# Out:
#   stu_first_name stu_last_name  marks                  email
# 0       Abhishek            TG     80  abhishek123@gmail.com
# 1          Akash            TG     90      akash54@gmail.com
# 2           Manu            TS     75       manu87@gmail.com
# 3          Manju            TM     78      manju56@gmail.com

# %%
# permenent indexing

df.set_index('stu_first_name',inplace = True)

# %%
df
# Out:
#                stu_last_name  marks                  email
# stu_first_name
# Abhishek                  TG     80  abhishek123@gmail.com
# Akash                     TG     90      akash54@gmail.com
# Manu                      TS     75       manu87@gmail.com
# Manju                     TM     78      manju56@gmail.com

# %%
df[0] # (it is error because now index is stu_name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.loc['Abhishek':'Manju','marks']
# Out:
# stu_first_name
# Abhishek    80
# Akash       90
# Manu        75
# Manju       78
# Name: marks, dtype: int64

# %%
# rest the index

df.reset_index(inplace = True)

# %%
df
# Out:
#   stu_first_name stu_last_name  marks                  email
# 0       Abhishek            TG     80  abhishek123@gmail.com
# 1          Akash            TG     90      akash54@gmail.com
# 2           Manu            TS     75       manu87@gmail.com
# 3          Manju            TM     78      manju56@gmail.com

# %%
df.loc[1:2,'marks']
# Out:
# 1    90
# 2    75
# Name: marks, dtype: int64

# %%
# set the index
import pandas as pd
df1 = pd.read_csv("D:/New folder/stack-overflow-developer-survey-2021/survey_results_public.csv",index_col = 'ResponseId')
df1
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df1.reset_index(inplace = True)

# %%
df1.head(50)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                     I am a developer by profession
# 1            2             I am a student who is learning to code
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# 5            6             I am a student who is learning to code
# 6            7                        I code primarily as a hobby
# 7            8             I am a student who is learning to code
# 8            9                     I am a developer by profession
# 9           10                     I am a developer by profession
# 10          11                     I am a developer by profession
# 11          12                     I am a developer by profession
# 12          13                     I am a developer by profession
# ...

# %%
# data filtering
# in this we can specify the single columns


a = df['stu_first_name'] == 'Akash' 
df[a]
# Out:
#   stu_first_name stu_last_name  marks              email
# 1          Akash            TG     90  akash54@gmail.com

# %%
b = (df['stu_first_name'] =='Abhishek') & (df['marks'] == 80)

# %%
# in this we can specify the multiple columns

df.loc[b,['email','marks']]
# Out:
#                    email  marks
# 0  abhishek123@gmail.com     80

# %%
df[b]
# Out:
#   stu_first_name stu_last_name  marks                  email
# 0       Abhishek            TG     80  abhishek123@gmail.com

# %%
# Ravindra question regardion more than 1d list data append or insert
a = [[1,2,3],[4,5,6]]

# %%
a
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
a[1].insert(2,20)

# %%
a
# Out:
# [[1, 2, 3], [4, 5, 20, 6]]

# %%
country = ['India','United States','United Kingdom','Germany','Canada']

a = df1['Country'].isin(country)

df1.loc[a,'Country']
# Out:
# 8          India
# 12       Germany
# 17        Canada
# 20       Germany
# 22         India
#           ...
# 83415    Germany
# 83417      India
# 83424    Germany
# 83432     Canada
# 83437     Canada
# Name: Country, Length: 19148, dtype: object

# %%
b = df1['LanguageHaveWorkedWith'].str.contains('Python',na = False)

df1.loc[b,'LanguageHaveWorkedWith']
# Out:
# 1                                      JavaScript;Python
# 2                               Assembly;C;Python;R;Rust
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# 5      C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 9                                             C++;Python
#                              ...
# 989     Bash/Shell;HTML/CSS;JavaScript;Python;TypeScript
# 991                   HTML/CSS;JavaScript;Node.js;Python
# 992    C++;HTML/CSS;JavaScript;Node.js;Python;SQL;Typ...
# 994    Bash/Shell;C;Go;HTML/CSS;JavaScript;Matlab;Nod...
# 995    C;C#;C++;Dart;HTML/CSS;JavaScript;Kotlin;Node....
# Name: LanguageHaveWorkedWith, Length: 493, dtype: object

# %%
df1.loc[b][1:3]
# Out:
#    ResponseId                                         MainBranch  \
# 2           3  I am not primarily a developer, but I write co...
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 2                                 Student, full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 2                                 Russian Federation      NaN        NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN    England
#
#                                            EdLevel     Age1stCode  \
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
#
#                                            LearnCode YearsCode  ...  \
# 2  Other online resources (ex: videos, blogs, etc...       NaN  ...
# ...

# %%
# update the values

a = df['stu_first_name'][0] = 'Abhi'
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_7084\1096590128.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a = df['stu_first_name'][0] = 'Abhi'

# %%
df
# Out:
#   stu_first_name stu_last_name  marks                  email
# 0           Abhi            TG     80  abhishek123@gmail.com
# 1          Akash            TG     90      akash54@gmail.com
# 2           Manu            TS     75       manu87@gmail.com
# 3          Manju            TM     78      manju56@gmail.com

# %%
a = df['stu_first_name'][0] = 'Abhishek'
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_7084\2751188659.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a = df['stu_first_name'][0] = 'Abhishek'

# %%
df
# Out:
#   stu_first_name stu_last_name  marks                  email
# 0       Abhishek            TG     80  abhishek123@gmail.com
# 1          Akash            TG     90      akash54@gmail.com
# 2           Manu            TS     75       manu87@gmail.com
# 3          Manju            TM     78      manju56@gmail.com

# %%
filt = df['stu_first_name'] == 'Abhishek'
df[filt]['email'] = '4mh17ec002@gmail.com'

# it throws the error
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_7084\1133159049.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[filt]['email'] = '4mh17ec002@gmail.com'

# %%
filt = df['stu_first_name'] == 'Abhishek'
df.loc[filt,'email'] = '4mh17ec002@gmail.com'

# %%
df
# Out:
#   stu_first_name stu_last_name  marks                 email
# 0       Abhishek            TG     80  4mh17ec002@gmail.com
# 1          Akash            TG     90     akash54@gmail.com
# 2           Manu            TS     75      manu87@gmail.com
# 3          Manju            TM     78     manju56@gmail.com

# %%
# convert upper to lower case

df['stu_last_name'] =df['stu_last_name'].str.lower()
df
# Out:
#   stu_first_name stu_last_name  marks                 email
# 0       Abhishek            tg     80  4mh17ec002@gmail.com
# 1          Akash            tg     90     akash54@gmail.com
# 2           Manu            ts     75      manu87@gmail.com
# 3          Manju            tm     78     manju56@gmail.com

# %%
df['stu_last_name'] =df['stu_last_name'].str.upper()
df
# Out:
#   stu_first_name stu_last_name  marks                 email
# 0       Abhishek            TG     80  4mh17ec002@gmail.com
# 1          Akash            TG     90     akash54@gmail.com
# 2           Manu            TS     75      manu87@gmail.com
# 3          Manju            TM     78     manju56@gmail.com

# %%
# apply

df['email'].apply(len)
# Out:
# 0    20
# 1    17
# 2    16
# 3    17
# Name: email, dtype: int64

# %%
# this is one way for lower to upper and another way is using apply function

df['email'] = df['email'].str.upper()
df
# Out:
#   stu_first_name stu_last_name  marks                 email
# 0       Abhishek            TG     80  4MH17EC002@GMAIL.COM
# 1          Akash            TG     90     AKASH54@GMAIL.COM
# 2           Manu            TS     75      MANU87@GMAIL.COM
# 3          Manju            TM     78     MANJU56@GMAIL.COM

# %%
def apply_lower(email):
    return email.lower()

# %%
df['email'] = df['email'].apply(apply_lower)
df
# Out:
#   stu_first_name stu_last_name  marks                 email
# 0       Abhishek            TG     80  4mh17ec002@gmail.com
# 1          Akash            TG     90     akash54@gmail.com
# 2           Manu            TS     75      manu87@gmail.com
# 3          Manju            TM     78     manju56@gmail.com

# %%
# this is also one more method for case conversion
# i am not using equal so thats why it is not impact on table
df['email'].apply(lambda x:x.upper())
# Out:
# 0    4MH17EC002@GMAIL.COM
# 1       AKASH54@GMAIL.COM
# 2        MANU87@GMAIL.COM
# 3       MANJU56@GMAIL.COM
# Name: email, dtype: object

# %%
import pandas as pd
df.apply(pd.Series.min)
# Out:
# stu_first_name                Abhishek
# stu_last_name                       TG
# marks                               75
# email             4mh17ec002@gmail.com
# dtype: object

# %%
df.applymap(str.lower) # it is applicable only when table contains only string values but in this table is contains one result as int value
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7084\357608748.py in <module>
# ----> 1 df.applymap(str.lower)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in applymap(self, func, na_action, **kwargs)
#    8931             return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
#    8932
# -> 8933         return self.apply(infer).__finalize__(self, "applymap")
#    8934
#    8935     # ----------------------------------------------------------------------
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
#    8850     def applymap(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
# ...

# %%
# df['stu_last_name'] = df['stu_last_name'].map({'TG':'Thippur gangadhar','TS':'Thippur sannaswamy nayaka'}) #permenent

df['stu_last_name'].map({'TG':'Thippur gangadhar','TS':'Thippur sannaswamy nayaka'}) # it is temerory changing
# if we are missed to map any one then by default it will take NaN so to avoid this we come up with replace
# Out:
# 0            Thippur gangadhar
# 1            Thippur gangadhar
# 2    Thippur sannaswamy nayaka
# 3                          NaN
# Name: stu_last_name, dtype: object

# %%
# repalce

df['stu_last_name'].replace({'TG':'Thippur gangadhar','TS':'Thippur sannaswamy nayaka'}) # it is temerory changing
# Out:
# 0            Thippur gangadhar
# 1            Thippur gangadhar
# 2    Thippur sannaswamy nayaka
# 3                           TM
# Name: stu_last_name, dtype: object

# %%
# rename column names

df.rename(columns={'stu_first_name':'first_name','stu_last_name':'last_name'},inplace = True)
df
# Out:
#   first_name last_name  marks                 email
# 0   Abhishek        TG     80  4mh17ec002@gmail.com
# 1      Akash        TG     90     akash54@gmail.com
# 2       Manu        TS     75      manu87@gmail.com
# 3      Manju        TM     78     manju56@gmail.com

# %%
df1.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
# create new column by combining two columns

df['first_name']+' '+df['last_name']
# Out:
# 0    Abhishek TG
# 1       Akash TG
# 2        Manu TS
# 3       Manju TM
# dtype: object

# %%
df['full_name'] = df['first_name']+' '+df['last_name']
df
# Out:
#   first_name last_name  marks                 email    full_name
# 0   Abhishek        TG     80  4mh17ec002@gmail.com  Abhishek TG
# 1      Akash        TG     90     akash54@gmail.com     Akash TG
# 2       Manu        TS     75      manu87@gmail.com      Manu TS
# 3      Manju        TM     78     manju56@gmail.com     Manju TM

# %%
# delete or drop the columns

df.drop(columns = ['first_name','last_name']) #temporory deleting the columns if write 'inplace = True ' then it will permenently changed
# Out:
#    marks                 email    full_name
# 0     80  4mh17ec002@gmail.com  Abhishek TG
# 1     90     akash54@gmail.com     Akash TG
# 2     75      manu87@gmail.com      Manu TS
# 3     78     manju56@gmail.com     Manju TM

# %%
df
# Out:
#   first_name last_name  marks                 email    full_name
# 0   Abhishek        TG     80  4mh17ec002@gmail.com  Abhishek TG
# 1      Akash        TG     90     akash54@gmail.com     Akash TG
# 2       Manu        TS     75      manu87@gmail.com      Manu TS
# 3      Manju        TM     78     manju56@gmail.com     Manju TM

# %%
df.drop(columns = ['first_name','last_name'],inplace = True)

# %%
df
# Out:
#    marks                 email    full_name
# 0     80  4mh17ec002@gmail.com  Abhishek TG
# 1     90     akash54@gmail.com     Akash TG
# 2     75      manu87@gmail.com      Manu TS
# 3     78     manju56@gmail.com     Manju TM

# %%
# it can split the column and by using expand = True we can made it as a columns after splitting
df['full_name'].str.split(' ',expand = True)
# Out:
#           0   1
# 0  Abhishek  TG
# 1     Akash  TG
# 2      Manu  TS
# 3     Manju  TM

# %%
# creating column name for splitted columns

df[['first_name','last_name']] = df['full_name'].str.split(' ',expand = True) # 
df
# Out:
#    marks                 email    full_name first_name last_name
# 0     80  4mh17ec002@gmail.com  Abhishek TG   Abhishek        TG
# 1     90     akash54@gmail.com     Akash TG      Akash        TG
# 2     75      manu87@gmail.com      Manu TS       Manu        TS
# 3     78     manju56@gmail.com     Manju TM      Manju        TM

# %%
# it is also same way as above step creating column name for splitted columns 

df.loc[:,['first_name','last_name']] = df['full_name'].str.split(' ',expand = True)

# %%
df
# Out:
#    marks                 email    full_name  first_name  last_name
# 0     80  4mh17ec002@gmail.com  Abhishek TG         NaN        NaN
# 1     90     akash54@gmail.com     Akash TG         NaN        NaN
# 2     75      manu87@gmail.com      Manu TS         NaN        NaN
# 3     78     manju56@gmail.com     Manju TM         NaN        NaN

# %%
data = {'stu_first_name':['rakesh','rajesh'],'stu_last_name':['KS','PJ'],'marks':[72,77]}
df2 = pd.DataFrame(data)
df2
# Out:
#   stu_first_name stu_last_name  marks
# 0         rakesh            KS     72
# 1         rajesh            PJ     77

# %%
df.append(df2,ignore_index = True,sort=False)
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_7084\206764800.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df2,ignore_index = True,sort=False)
#   stu_first_name stu_last_name  marks                  email first_name  \
# 0       Abhishek            TG     80  abhishek123@gmail.com        NaN
# 1          Akash            TG     90      akash54@gmail.com        NaN
# 2           Manu            TS     75       manu87@gmail.com        NaN
# 3          Manju            TM     78      manju56@gmail.com        NaN
# 4            NaN           NaN     72                    NaN     rakesh
# 5            NaN           NaN     77                    NaN     rajesh
# 6         rakesh            KS     72                    NaN        NaN
# 7         rajesh            PJ     77                    NaN        NaN
#
#   last_name
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# ...

# %%
df = df.append(df2) #index values ore not correct to overcome this we can use ignore index = True
df
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_7084\3448984750.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2) #index values ore not correct to overcome this we can use ignore index = True
#   stu_first_name stu_last_name  marks                  email first_name  \
# 0       Abhishek            TG     80  abhishek123@gmail.com        NaN
# 1          Akash            TG     90      akash54@gmail.com        NaN
# 2           Manu            TS     75       manu87@gmail.com        NaN
# 3          Manju            TM     78      manju56@gmail.com        NaN
# 4            NaN           NaN     72                    NaN     rakesh
# 5            NaN           NaN     77                    NaN     rajesh
# 0         rakesh            KS     72                    NaN        NaN
# 1         rajesh            PJ     77                    NaN        NaN
#
#   last_name
# ...

# %%
df = df.append(df2,ignore_index = True,sort=False)
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_7084\479368644.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2,ignore_index = True,sort=False)

# %%
df
# Out:
#   stu_first_name stu_last_name  marks                  email
# 0       Abhishek            TG     80  abhishek123@gmail.com
# 1          Akash            TG     90      akash54@gmail.com
# 2           Manu            TS     75       manu87@gmail.com
# 3          Manju            TM     78      manju56@gmail.com
# 4         rakesh            KS     72                    NaN
# 5         rajesh            PJ     77                    NaN

# %%
# remove the rows or data

df.drop(index =5 ,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7084\1274595195.py in <module>
#       1 # remove the rows or data
#       2
# ----> 3 df.drop(index =5 ,inplace = True)
#       4 df
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
df
# Out:
#   stu_first_name stu_last_name  marks                  email
# 0       Abhishek            TG     80  abhishek123@gmail.com
# 1          Akash            TG     90      akash54@gmail.com
# 2           Manu            TS     75       manu87@gmail.com
# 3          Manju            TM     78      manju56@gmail.com
# 4         rakesh            KS     72                    NaN

# %%
# remove the rows through condition

a = df[df['stu_first_name']=='rakesh']

a
# Out:
# Empty DataFrame
# Columns: [stu_first_name, stu_last_name, marks, email]
# Index: []

# %%
df.drop(a.index)
# Out:
#   stu_first_name stu_last_name  marks                  email
# 0       Abhishek            TG     80  abhishek123@gmail.com
# 1          Akash            TG     90      akash54@gmail.com
# 2           Manu            TS     75       manu87@gmail.com
# 3          Manju            TM     78      manju56@gmail.com

# %%
# sort the values base on the columns

df.sort_values(by = ['stu_last_name','stu_first_name'],ascending = [True,False])
# Out:
#   stu_first_name stu_last_name  marks                  email
# 1          Akash            TG     90      akash54@gmail.com
# 0       Abhishek            TG     80  abhishek123@gmail.com
# 3          Manju            TM     78      manju56@gmail.com
# 2           Manu            TS     75       manu87@gmail.com

# %%
# sort the values base on the columns

df.sort_values(by = 'stu_first_name',ascending = False)
# Out:
#   stu_first_name stu_last_name  marks                  email
# 2           Manu            TS     75       manu87@gmail.com
# 3          Manju            TM     78      manju56@gmail.com
# 1          Akash            TG     90      akash54@gmail.com
# 0       Abhishek            TG     80  abhishek123@gmail.com

# %%
# sort the values base on the columns

df.sort_values(by = ['stu_last_name','stu_first_name'],ascending = [True,False],inplace = True)

# %%
df
# Out:
#   stu_first_name stu_last_name  marks                  email
# 1          Akash            TG     90      akash54@gmail.com
# 0       Abhishek            TG     80  abhishek123@gmail.com
# 3          Manju            TM     78      manju56@gmail.com
# 2           Manu            TS     75       manu87@gmail.com

# %%
df.sort_index(inplace = True)

# %%
df
# Out:
#   stu_first_name stu_last_name  marks                  email
# 0       Abhishek            TG     80  abhishek123@gmail.com
# 1          Akash            TG     90      akash54@gmail.com
# 2           Manu            TS     75       manu87@gmail.com
# 3          Manju            TM     78      manju56@gmail.com

# %%
# select top 2 higest marks

df.nlargest(2,'marks')
# Out:
#   stu_first_name stu_last_name  marks                  email
# 1          Akash            TG     90      akash54@gmail.com
# 0       Abhishek            TG     80  abhishek123@gmail.com

# %%
df['marks'].nlargest(3)
# Out:
# 1    90
# 0    80
# 3    78
# Name: marks, dtype: int64

# %%
# select top 2 smallest marks

df.nsmallest(2,'marks')
# Out:
#   stu_first_name stu_last_name  marks              email
# 2           Manu            TS     75   manu87@gmail.com
# 3          Manju            TM     78  manju56@gmail.com

# %%
# count

df['marks'].count()
# Out:
# 4

# %%
# value count

df['stu_last_name'].value_counts()
# Out:
# TG    2
# TS    1
# TM    1
# Name: stu_last_name, dtype: int64

# %%
df.count()
# Out:
# stu_first_name    4
# stu_last_name     4
# marks             4
# email             4
# dtype: int64

# %%
df1[['Country','ConvertedCompYearly']].head(50)
# Out:
#                                               Country  ConvertedCompYearly
# 0                                            Slovakia              62268.0
# 1                                         Netherlands                  NaN
# 2                                  Russian Federation                  NaN
# 3                                             Austria                  NaN
# 4   United Kingdom of Great Britain and Northern I...                  NaN
# 5                            United States of America                  NaN
# 6                            United States of America                  NaN
# 7                                            Malaysia                  NaN
# 8                                               India                  NaN
# 9                                              Sweden              51552.0
# 10  United Kingdom of Great Britain and Northern I...                  NaN
# ...

# %%
import pandas as pd
df3 = pd.read_csv("D:/New folder/stack-overflow-developer-survey-2019/survey_results_public.csv")
df3
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df3[df3['Country'] =='India']['SocialMedia'].value_counts().head(30)
# Out:
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
# groupby multiple coulumns
df3.groupby(['Country','SocialMedia'])

# %%
x = df3.groupby('Country')

# %%
x.get_group('India')
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
x['SocialMedia'].value_counts().head(20)
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#              LinkedIn                     1
#              Twitter                      1
# Albania      WhatsApp                    18
#              Facebook                    16
#              Instagram                   13
#              YouTube                     10
#              Twitter                      8
#              LinkedIn                     7
#              Reddit                       6
#              I don't use social media     4
#              Snapchat                     1
#              WeChat 微信                    1
# Algeria      YouTube                     42
#              Facebook                    41
#              Twitter                     14
# Name: SocialMedia, dtype: int64

# %%
x['SocialMedia'].value_counts().loc['China'].head(20)
# Out:
# SocialMedia
# WeChat 微信                   403
# YouTube                      53
# Weibo 新浪微博                   42
# I don't use social media     27
# Twitter                      27
# Reddit                       12
# LinkedIn                     11
# Facebook                      8
# Instagram                     7
# Youku Tudou 优酷                7
# WhatsApp                      3
# VK ВКонта́кте                 1
# Name: SocialMedia, dtype: int64

# %%
# it is in percentage

x['SocialMedia'].value_counts(normalize = True).loc['China'].head(20)
# Out:
# SocialMedia
# WeChat 微信                   0.670549
# YouTube                     0.088186
# Weibo 新浪微博                  0.069884
# I don't use social media    0.044925
# Twitter                     0.044925
# Reddit                      0.019967
# LinkedIn                    0.018303
# Facebook                    0.013311
# Instagram                   0.011647
# Youku Tudou 优酷              0.011647
# WhatsApp                    0.004992
# VK ВКонта́кте               0.001664
# Name: SocialMedia, dtype: float64

# %%
x['ConvertedComp'].median().loc['India']
# Out:
# 10080.0

# %%
x['ConvertedComp'].agg(['median','mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
x['ConvertedComp'].agg(['median','mean']).loc['India']
# Out:
# median    10080.000000
# mean      28057.664916
# Name: India, dtype: float64

# %%
filt = df3['Country'] == 'United Kingdom'

# %%
df3.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 2384

# %%
df3.loc[:]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 36443

# %%
python_known_people = x['LanguageWorkedWith'].apply(lambda x :x.str.contains('Python').sum())  
python_known_people
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
x['LanguageWorkedWith'].apply(lambda x :x.str.contains('Python').sum()).loc['India']
# Out:
# 3105

# %%
no_country_people = df3['Country'].value_counts()
no_country_people
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
df4 = pd.concat([no_country_people,python_known_people],axis = 'columns',sort =False)
df4
# Out:
#                    Country  LanguageWorkedWith
# United States        20949               10083
# India                 9061                3105
# Germany               5866                2451
# United Kingdom        5737                2384
# Canada                3395                1558
# ...                    ...                 ...
# Tonga                    1                   0
# Timor-Leste              1                   1
# North Korea              1                   0
# Brunei Darussalam        1                   0
# Chad                     1                   0
#
# [179 rows x 2 columns]

# %%
df4.rename(columns = {'Country':'people_count_country','LanguageWorkedWith':'python_know_country'},inplace = True)

# %%
df4
# Out:
#                    people_count_country  python_know_country
# United States                     20949                10083
# India                              9061                 3105
# Germany                            5866                 2451
# United Kingdom                     5737                 2384
# Canada                             3395                 1558
# ...                                 ...                  ...
# Tonga                                 1                    0
# Timor-Leste                           1                    1
# North Korea                           1                    0
# Brunei Darussalam                     1                    0
# Chad                                  1                    0
#
# [179 rows x 2 columns]

# %%
df4['precofpeoplePython'] = (df4['python_know_country'] / df4['people_count_country']) *100

# %%
df4.sort_values(by = 'precofpeoplePython',ascending = False)
# Out:
#                                   people_count_country  python_know_country  \
# Sao Tome and Principe                                1                    1
# Timor-Leste                                          1                    1
# Dominica                                             1                    1
# Niger                                                1                    1
# Turkmenistan                                         7                    6
# ...                                                ...                  ...
# Cape Verde                                           3                    0
# Lao People's Democratic Republic                     3                    0
# Malawi                                               2                    0
# Liberia                                              2                    0
# Chad                                                 1                    0
#
#                                   precofpeoplePython
# ...

# %%
df.to_csv()
